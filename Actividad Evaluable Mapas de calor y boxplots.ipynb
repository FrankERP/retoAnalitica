# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('avocado.csv') 

pd.set_option('display.max_rows', 100)
print(data)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
col1 = data['AveragePrice']
col2 = data['Total Volume']
col3 = data['4046']
col4 = data['4225']
col5 = data['4770']


bplot = [col1, col2, col3,col4,col5]
bplot2 = [col6, col7, col8,col9,col10]
fig = plt.figure(figsize=(10,7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(bplot)
plt.show(bp)

# %%
col6 = data['Total Bags']
col7 = data['Small Bags']
col8 = data['Large Bags']
col9 = data['XLarge Bags']
col10 = data['year']
col11 = data['region']
bplot2 = [col6, col7, col8,col9,col10]
fig = plt.figure(figsize=(10,7))
ax = fig.add_axes([0, 0, 1, 1])
bp2 = ax.boxplot(bplot2)
plt.show(bp2)

# %%
plt.hist(data['AveragePrice'])
plt.show()
plt.hist(data['Total Volume'])
plt.show()
plt.hist(data['4046'])
plt.show()
plt.hist(data['4225'])
plt.show()
plt.hist(data['4770'])
plt.show()

# %%
plt.hist(data['Total Bags'])
plt.show()
plt.hist(data['Small Bags'])
plt.show()
plt.hist(data['Large Bags'])
plt.show()
plt.hist(data['XLarge Bags'])
plt.show()
plt.hist(data['year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hplot=[col1, col2, col3,col4,col5,col6,col7,col8,col9,col10]
ax = sns.heatmap(hplot)
plt.show()

# %%
hplot=[col8,col9,col10]
ax = sns.heatmap(hplot)
plt.show()

# %%
hplot=[col1,col2,col3]
ax = sns.heatmap(hplot)
plt.show()

# %%
hplot=[col4,col5,col6]
ax = sns.heatmap(hplot)
plt.show()

# %%
hplot=[col7,col8,col9]
ax = sns.heatmap(hplot)
plt.show()

# %%
hplot=[col1,col10]
ax = sns.heatmap(hplot)
plt.show()

# %% [markdown]
# Responde las siguientes preguntas:
# ¿Hay alguna variable que no aporta información?
#     Sobre las variables '4046', '4225'y'4770' no podemos saber si la información es relevante, ya que este nombre de la columna no nos aporta ningún contexto sobre los datos para llamarlos información.
#
# Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?
#     Eliminaría las variables antes mencionadas. Pero, si hablamos sobre el análisis visual de las variables por medio de las gráficas, hay varias variables que no son capaces de aportar mucho, como lo son 'year','region' y la primera columna que no tiene nombre.
# ¿Existen variables que tengan datos extraños?
#     La variable que está en la primera columna, sus datos no sé qué puedan significar, tampoco los de las variables '4046', '4224', '4770'.
# Si comparas las variables, ¿todas están en rangos similares?
#     A excepción de 'Average Price'y 'year', todas las variables se encunetran en el rango de un mínimo promedio de 0 y un máximo que va entre 10^7 y 10^6.
#
# ¿Crees que esto afecte?
#     Yo creo que debería ser algo bueno que su rango de valores sea similar; sin embargo, los datos están muy dispersos y la mayoría se encuentra ubicados en un conjunto menor del rango total de la variable. Creo que esto sí puede afectar de una manera negativa nuestro análisis.
#
# ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?
#     Los grupos 'Large Bag', 'Small Bag', 'XLarge Bag' y 'Total Bags' son grupos que se parecen, supongo que tiene que ver con que los 4 hacen referencia a diferentes tipos del mismo producto.
